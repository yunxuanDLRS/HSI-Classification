# %% [markdown]
# csm-ssrn框架采用三层并行残差网络结构，利用不同的三维卷积核从各自残差块中连续学习光谱和空间特征。
# 将提取的深度多尺度特征进行叠加，输入到三维注意力模块中，从通道和空间域两个方面增强图像特征的表现力，从而提高分类精度。

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
